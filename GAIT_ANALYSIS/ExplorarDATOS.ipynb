# %% [markdown]
# # LABORATORIO BIOMECANICA: ANALISIS DE MARCHA NORMAL (control)  VS MARCHA UTILIZANDO OTP

# %% [markdown]
# # ANÁLISIS EXPLORATORIO DE DATOS DE MARCHA UTILIZANDO OTP DE PIE IZQUIERDO

# %%
import pandas as pd

# %% [markdown]
# Cargamos los datos de 'CONTROL' en la variable control, y los datos 'OTP' en la variable otp

# %%
control = pd.read_csv('datos_control.csv')
otp = pd.read_csv('marchaOTP.csv')

# %%
control.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Data columns (total 48 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   XHIP1         274 non-null    float64
#  1   YHIP1         274 non-null    float64
#  2   ZHIP1         274 non-null    float64
#  3   XHIP2         276 non-null    float64
#  4   YHIP2         276 non-null    float64
#  5   ZHIP2         276 non-null    float64
#  6   XHIP3         276 non-null    float64
#  7   YHIP3         276 non-null    float64
#  8   ZHIP3         276 non-null    float64
#  9   XHIP4         276 non-null    float64
#  10  YHIP4         276 non-null    float64
#  11  ZHIP4         276 non-null    float64
#  12  XRightThigh1  276 non-null    float64
#  13  YRightThigh1  276 non-null    float64
#  14  ZRightThigh1  276 non-null    float64
#  15  XRightThigh2  276 non-null    float64
#  16  YRightThigh2  276 non-null    float64
# ...

# %%
otp.describe()
# Out:
#             XHIP1          YHIP1       ZHIP1       XHIP2        YHIP2  \
# count  329.000000     329.000000  329.000000  329.000000   329.000000
# mean    68.743183    -443.831940  898.666092 -134.575617   494.475705
# std     41.341252   17792.911829    9.773933   40.966410   705.213283
# min      3.520571 -321944.000000  880.556152 -201.464920  -710.698425
# 25%     31.326439     -72.136223  891.352417 -172.743958  -113.956970
# 50%     63.005871     527.685059  896.828735 -141.272797   482.371094
# 75%    108.511848    1145.631958  905.019348  -92.294762  1119.827515
# max    134.418488    1756.026001  920.180847  -73.028648  1711.182495
#
#             ZHIP2       XHIP3          YHIP3       ZHIP3  XRightThigh1  ...  \
# count  329.000000  329.000000     329.000000  329.000000    329.000000  ...
# mean   891.770819  -84.669750    -900.867632  865.281314   -149.618808  ...
# std      6.903458   41.989610   22008.452147    7.252056     40.898258  ...
# ...

# %% [markdown]
# # Gráficas ubicación espacial 3D de 13 marcadores captados por 8 camaras

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot3D(otp['XHIP1'][0], otp['YHIP1'][0], otp['ZHIP1'][0], '*r')
ax.plot3D(otp['XHIP2'][0], otp['YHIP2'][0], otp['ZHIP2'][0], '*r')
ax.plot3D(otp['XHIP3'][0], otp['YHIP3'][0], otp['ZHIP3'][0], '*r')
ax.plot3D(otp['XRightThigh1'][0], otp['YRightThigh1'][0], otp['ZRightThigh1'][0], '*r')
ax.plot3D(otp['XRightThigh3'][0], otp['YRightThigh3'][0], otp['ZRightThigh3'][0], '*r')
ax.plot3D(otp['XLeftThigh1'][0], otp['YLeftThigh1'][0], otp['ZLeftThigh1'][0], '*r')
ax.plot3D(otp['XLeftThigh3'][0], otp['YLeftThigh3'][0], otp['ZLeftThigh3'][0], '*r')
ax.plot3D(otp['XLKNEE'][0], otp['YLKNEE'][0], otp['ZLKNEE'][0], '*r')
ax.plot3D(otp['XLANK'][0], otp['YLANK'][0], otp['ZLANK'][0], '*r')
ax.plot3D(otp['XLeftTibia3'][0], otp['YLeftTibia3'][0], otp['ZLeftTibia3'][0], '*r')
ax.plot3D(otp['XRKNEE'][0], otp['YRKNEE'][0], otp['ZRKNEE'][0], '*r')
ax.plot3D(otp['XRANK'][0], otp['YRANK'][0], otp['ZRANK'][0], '*r')
ax.plot3D(otp['XRightTibia3'][0], otp['YRightTibia3'][0], otp['ZRightTibia3'][0], '*r')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = plt.axes(projection='3d')

ax.axes.set_xlim3d(left=-100, right=300) 
ax.axes.set_ylim3d(bottom=-500, top=1500) 
ax.axes.set_zlim3d(bottom=-5, top=900)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

for i in range(300):
    ax.plot3D(otp['XHIP1'][i], otp['YHIP1'][i], otp['ZHIP1'][i], '*r')
    ax.plot3D(otp['XHIP2'][i], otp['YHIP2'][i], otp['ZHIP2'][i], '*b')
    ax.plot3D(otp['XHIP3'][i], otp['YHIP3'][i], otp['ZHIP3'][i], '*g')
    ax.plot3D(otp['XRightThigh1'][i], otp['YRightThigh1'][i], otp['ZRightThigh1'][i], '*r')
    ax.plot3D(otp['XRightThigh3'][i], otp['YRightThigh3'][i], otp['ZRightThigh3'][i], '*r')
    ax.plot3D(otp['XLeftThigh1'][i], otp['YLeftThigh1'][i], otp['ZLeftThigh1'][i], '*r')
    ax.plot3D(otp['XLeftThigh3'][i], otp['YLeftThigh3'][i], otp['ZLeftThigh3'][i], '*r')
    ax.plot3D(otp['XLKNEE'][i], otp['YLKNEE'][i], otp['ZLKNEE'][i], '*r')
    ax.plot3D(otp['XLANK'][i], otp['YLANK'][i], otp['ZLANK'][i], '*r')
    ax.plot3D(otp['XLeftTibia3'][i], otp['YLeftTibia3'][i], otp['ZLeftTibia3'][i], '*r')
    ax.plot3D(otp['XRKNEE'][i], otp['YRKNEE'][i], otp['ZRKNEE'][i], '*r')
    ax.plot3D(otp['XRANK'][i], otp['YRANK'][i], otp['ZRANK'][i], '*r')
    ax.plot3D(otp['XRightTibia3'][i], otp['YRightTibia3'][i], otp['ZRightTibia3'][i], '*r')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = plt.axes(projection='3d')

ax.axes.set_xlim3d(left=-100, right=300) 
ax.axes.set_ylim3d(bottom=-500, top=2000) 
ax.axes.set_zlim3d(bottom=-5, top=800)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

for i in range(200):
    ax.plot3D(control['XHIP1'][i], control['YHIP1'][i], control['ZHIP1'][i], '*r')
    ax.plot3D(control['XHIP2'][i], control['YHIP2'][i], control['ZHIP2'][i], '*r')
    ax.plot3D(control['XHIP3'][i], control['YHIP3'][i], control['ZHIP3'][i], '*r')
    ax.plot3D(control['XRightThigh1'][i], control['YRightThigh1'][i], control['ZRightThigh1'][i], '*r')
    ax.plot3D(control['XRightThigh3'][i], control['YRightThigh3'][i], control['ZRightThigh3'][i], '*r')
    ax.plot3D(control['XLeftThigh1'][i], control['YLeftThigh1'][i], control['ZLeftThigh1'][i], '*r')
    ax.plot3D(control['XLeftThigh3'][i], control['YLeftThigh3'][i], control['ZLeftThigh3'][i], '*r')
    ax.plot3D(control['XLKNEE'][i], control['YLKNEE'][i], control['ZLKNEE'][i], '*r')
    ax.plot3D(control['XLANK'][i], control['YLANK'][i], control['ZLANK'][i], '*r')
    ax.plot3D(control['XLeftTibia3'][i], control['YLeftTibia3'][i], otp['ZLeftTibia3'][i], '*r')
    ax.plot3D(control['XRKNEE'][i], control['YRKNEE'][i], control['ZRKNEE'][i], '*r')
    ax.plot3D(control['XRANK'][i], control['YRANK'][i], control['ZRANK'][i], '*r')
    ax.plot3D(control['XRightTibia3'][i], control['YRightTibia3'][i], control['ZRightTibia3'][i], '*r')

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

from mpl_toolkits.mplot3d.axes3d import get_test_data


# set up a figure twice as wide as it is tall
fig = plt.figure(figsize=plt.figaspect(0.6))

# =============
# First subplot
# =============
# set up the axes for the first plot
ax = fig.add_subplot(1, 2, 1, projection='3d')
ax.axes.set_xlim3d(left=-100, right=300) 
ax.axes.set_ylim3d(bottom=-500, top=2000) 
ax.axes.set_zlim3d(bottom=-5, top=800)
ax.set_xlabel('x [mm]')
ax.set_ylabel('y [mm]')
ax.set_zlabel('z [mm]')
ax.set_title("CONTROL")

for i in range(200):
    ax.plot3D(control['XHIP1'][i], control['YHIP1'][i], control['ZHIP1'][i], marker="x", c="red")
    ax.plot3D(control['XHIP2'][i], control['YHIP2'][i], control['ZHIP2'][i], marker="x", c="blue")
    ax.plot3D(control['XHIP3'][i], control['YHIP3'][i], control['ZHIP3'][i], marker="x", c="orange")
    ax.plot3D(control['XRightThigh1'][i], control['YRightThigh1'][i], control['ZRightThigh1'][i], marker="x", c="green")
    ax.plot3D(control['XRightThigh3'][i], control['YRightThigh3'][i], control['ZRightThigh3'][i], marker="x", c="purple")
    ax.plot3D(control['XLeftThigh1'][i], control['YLeftThigh1'][i], control['ZLeftThigh1'][i], marker="x", c="brown")
    ax.plot3D(control['XLeftThigh3'][i], control['YLeftThigh3'][i], control['ZLeftThigh3'][i], marker="x", c="pink")
    ax.plot3D(control['XLKNEE'][i], control['YLKNEE'][i], control['ZLKNEE'][i], marker="x", c="gray")
    ax.plot3D(control['XLANK'][i], control['YLANK'][i], control['ZLANK'][i], marker="x", c="red")
    ax.plot3D(control['XLeftTibia3'][i], control['YLeftTibia3'][i], control['ZLeftTibia3'][i], marker="x", c="olive")
    ax.plot3D(control['XRKNEE'][i], control['YRKNEE'][i], control['ZRKNEE'][i], marker="x", c="cyan")
    ax.plot3D(control['XRANK'][i], control['YRANK'][i], control['ZRANK'][i], marker="x", c="red")
    ax.plot3D(control['XRightTibia3'][i], control['YRightTibia3'][i], control['ZRightTibia3'][i], marker="x", c="green")
    

ax.plot3D(control['XHIP1'][201], control['YHIP1'][201], control['ZHIP1'][201], label='HIP1',marker="x", c="red")
ax.plot3D(control['XHIP2'][201], control['YHIP2'][201], control['ZHIP2'][201], label='HIP2',marker="x", c="blue")
ax.plot3D(control['XHIP3'][201], control['YHIP3'][201], control['ZHIP3'][201], label='HIP3',marker="x", c="orange")
ax.plot3D(control['XRightThigh1'][201], control['YRightThigh1'][201], control['ZRightThigh1'][201], label='RightThigh1',marker="x", c="green")
ax.plot3D(control['XRightThigh3'][201], control['YRightThigh3'][201], control['ZRightThigh3'][201], label='RightThigh3',marker="x", c="purple")
ax.plot3D(control['XLeftThigh1'][201], control['YLeftThigh1'][201], control['ZLeftThigh1'][201], label='LeftThigh1',marker="x", c="brown")
ax.plot3D(control['XLeftThigh3'][201], control['YLeftThigh3'][201], control['ZLeftThigh3'][201], label='LeftThigh3',marker="x", c="pink")
ax.plot3D(control['XLKNEE'][201], control['YLKNEE'][201], control['ZLKNEE'][201], label='LKNEE',marker="x", c="gray")
ax.plot3D(control['XLANK'][201], control['YLANK'][201], control['ZLANK'][201], label='LANK',marker="x", c="red")
ax.plot3D(control['XLeftTibia3'][201], control['YLeftTibia3'][201], control['ZLeftTibia3'][201], label='LeftTibia3',marker="x", c="olive")
ax.plot3D(control['XRKNEE'][201], control['YRKNEE'][201], control['ZRKNEE'][201], label='RKNEE',marker="x", c="cyan")
ax.plot3D(control['XRANK'][201], control['YRANK'][201], control['ZRANK'][201], label='RANK',marker="x", c="red")
ax.plot3D(control['XRightTibia3'][201], control['YRightTibia3'][201], control['ZRightTibia3'][201], label='RightTibia3',marker="x", c="green")
#ax.legend(loc=(-20, 0), bbox_to_anchor=(0.5, -0.05),fancybox=True, shadow=True, ncol=6)



# ==============
# Second subplot
# ==============
# set up the axes for the second plot
ax = fig.add_subplot(1, 2, 2, projection='3d')

ax.axes.set_xlim3d(left=-100, right=300) 
ax.axes.set_ylim3d(bottom=-500, top=2000) 
ax.axes.set_zlim3d(bottom=-5, top=900)

ax.set_xlabel('x [mm]')
ax.set_ylabel('y [mm]')
ax.set_zlabel('z [mm]')

ax.set_title("MARCHA-OTP")
for i in range(200):
    ax.plot3D(otp['XHIP1'][i], otp['YHIP1'][i], otp['ZHIP1'][i], marker="x", c="red")
    ax.plot3D(otp['XHIP2'][i], otp['YHIP2'][i], otp['ZHIP2'][i], marker="x", c="blue")
    ax.plot3D(otp['XHIP3'][i], otp['YHIP3'][i], otp['ZHIP3'][i], marker="x", c="orange")
    ax.plot3D(otp['XRightThigh1'][i], otp['YRightThigh1'][i], otp['ZRightThigh1'][i], marker="x", c="green")
    ax.plot3D(otp['XRightThigh3'][i], otp['YRightThigh3'][i], otp['ZRightThigh3'][i], marker="x", c="purple")
    ax.plot3D(otp['XLeftThigh1'][i], otp['YLeftThigh1'][i], otp['ZLeftThigh1'][i], marker="x", c="brown")
    ax.plot3D(otp['XLeftThigh3'][i], otp['YLeftThigh3'][i], otp['ZLeftThigh3'][i], marker="x", c="pink")
    ax.plot3D(otp['XLKNEE'][i], otp['YLKNEE'][i], otp['ZLKNEE'][i], marker="x", c="gray")
    ax.plot3D(otp['XLANK'][i], otp['YLANK'][i], otp['ZLANK'][i], marker="x", c="red")
    ax.plot3D(otp['XLeftTibia3'][i], otp['YLeftTibia3'][i], otp['ZLeftTibia3'][i], marker="x", c="olive")
    ax.plot3D(otp['XRKNEE'][i], otp['YRKNEE'][i], otp['ZRKNEE'][i], marker="x", c="cyan")
    ax.plot3D(otp['XRANK'][i], otp['YRANK'][i], otp['ZRANK'][i], marker="x", c="red")
    ax.plot3D(otp['XRightTibia3'][i], otp['YRightTibia3'][i], otp['ZRightTibia3'][i], marker="x", c="green")
    

ax.plot3D(otp['XHIP1'][201], otp['YHIP1'][201], otp['ZHIP1'][201], marker="x", c="red")
ax.plot3D(otp['XHIP2'][201], otp['YHIP2'][201], otp['ZHIP2'][201], marker="x", c="blue")
ax.plot3D(otp['XHIP3'][201], otp['YHIP3'][201], otp['ZHIP3'][201], marker="x", c="orange")
ax.plot3D(otp['XRightThigh1'][201], otp['YRightThigh1'][201], otp['ZRightThigh1'][201], marker="x", c="green")
ax.plot3D(otp['XRightThigh3'][201], otp['YRightThigh3'][201], otp['ZRightThigh3'][201], marker="x", c="purple")
ax.plot3D(otp['XLeftThigh1'][201], otp['YLeftThigh1'][201], otp['ZLeftThigh1'][201], marker="x", c="brown")
ax.plot3D(otp['XLeftThigh3'][201], otp['YLeftThigh3'][201], otp['ZLeftThigh3'][201], marker="x", c="pink")
ax.plot3D(otp['XLKNEE'][201], otp['YLKNEE'][201], otp['ZLKNEE'][201], marker="x", c="gray")
ax.plot3D(otp['XLANK'][201], otp['YLANK'][201], otp['ZLANK'][201], marker="x", c="red")
ax.plot3D(otp['XLeftTibia3'][201], otp['YLeftTibia3'][201], otp['ZLeftTibia3'][201], marker="x", c="olive")
ax.plot3D(otp['XRKNEE'][201], otp['YRKNEE'][201], otp['ZRKNEE'][201],marker="x", c="cyan")
ax.plot3D(otp['XRANK'][201], otp['YRANK'][201], otp['ZRANK'][201], marker="x", c="red")
ax.plot3D(otp['XRightTibia3'][201], otp['YRightTibia3'][201], otp['ZRightTibia3'][201],marker="x", c="green")


fig.legend(loc=7)
fig.tight_layout()
fig.subplots_adjust(right=0.75)

# %% [markdown]
# # Gráficas de coordenads X,Y,Z con respecto al tiempo

# %% [markdown]
# ### CADERA 1 : Izquierda

# %%
fig, axs = plt.subplots(3,1)

plt.sca(axs[0])
plt.plot(otp['XHIP1'], label='OTP HIP1')
plt.plot(control['XHIP1'], label='control HIP1')
plt.title('Coordenada X HIP1')



plt.sca(axs[1])
plt.plot(otp['YHIP1'])
plt.plot(control['YHIP1'])
plt.title('Coordenada Y HIP1')


plt.sca(axs[2])
plt.plot(otp['ZHIP1'])
plt.plot(control['ZHIP1'])
plt.title('Coordenada Z HIP1')

fig.legend(loc=7)
fig.tight_layout()
fig.subplots_adjust(right=0.75)

# %% [markdown]
# ### Cadera 2: Derecha

# %%
fig, axs = plt.subplots(3,1)

plt.sca(axs[0])
plt.plot(otp['XHIP2'], label='OTP HIP2')
plt.plot(control['XHIP2'], label='control HIP2')
plt.title('Coordenada X HIP 2')



plt.sca(axs[1])
plt.plot(otp['YHIP2'])
plt.plot(control['YHIP2'])
plt.title('Coordenada Y HIP 2')


plt.sca(axs[2])
plt.plot(otp['ZHIP2'])
plt.plot(control['ZHIP2'])
plt.title('Coordenada Z HIP 2')

fig.legend(loc=7)
fig.tight_layout()
fig.subplots_adjust(right=0.75)

# %% [markdown]
# ### Rodilla Derecha

# %%
fig, axs = plt.subplots(3,1)

plt.sca(axs[0])
plt.plot(otp['XRKNEE'], label='OTP RKNEE')
plt.plot(control['XRKNEE'], label='control RKNEE')
plt.title('Coordenada X Right Knee')



plt.sca(axs[1])
plt.plot(otp['YRKNEE'])
plt.plot(control['YRKNEE'])
plt.title('Coordenada Y Right Knee')


plt.sca(axs[2])
plt.plot(otp['ZRKNEE'])
plt.plot(control['ZRKNEE'])
plt.title('Coordenada Z Right Knee')

fig.legend(loc=7)
fig.tight_layout()
fig.subplots_adjust(right=0.75)

# %% [markdown]
# ### Rodilla Izquierda

# %%
fig, axs = plt.subplots(3,1)

plt.sca(axs[0])
plt.plot(otp['XLKNEE'], label='OTP LKNEE')
plt.plot(control['XLKNEE'], label='control LKNEE')
plt.title('Coordenada X Left Knee')



plt.sca(axs[1])
plt.plot(otp['YLKNEE'])
plt.plot(control['YLKNEE'])
plt.title('Coordenada Y Left Knee')


plt.sca(axs[2])
plt.plot(otp['ZLKNEE'])
plt.plot(control['ZLKNEE'])
plt.title('Coordenada Z Left Knee')

fig.legend(loc=7)
fig.tight_layout()
fig.subplots_adjust(right=0.75)
